# %% [markdown]
# ## Data Generators Test
# This notebook concentrates on testing the custom data generators.
#
# The data generators are used to generate the data for experiments. The data generators are implemented in the `data/generator.py` file.

# %% [markdown]
# ### Packages and Modules

# %%
# %cd ..
# Out:
# D:\

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from data.generators import *

# %% [markdown]
# ### 1D Convex Data Generation

# %%
X_train, X_val, y_train, y_val = generate_1d_convex(n_samples=1000)
print(f"Training set size: {X_train.shape[0]} samples")
print(f"Validation set size: {X_val.shape[0]} samples")
# Out:
# Training set size: 800 samples
# Validation set size: 200 samples

# %% [markdown]
# Visualization for the 1D Convex Data Generation.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_train, y_train, label='Train Data', color='blue', alpha=0.5)
plt.scatter(X_val, y_val, label='Validation Data', color='green', alpha=0.5)
plt.title('1D Convex Function: Training and Validation Data')
plt.xlabel('X')
plt.ylabel('f(X) = X²')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("1D Convex Function - Summary Statistics:")
print(f"X_train: min={X_train.min()}, max={X_train.max()}, mean={X_train.mean():.4f}")
print(f"y_train: min={y_train.min()}, max={y_train.max()}, mean={y_train.mean():.4f}")
print(f"X_val: min={X_val.min()}, max={X_val.max()}, mean={X_val.mean():.4f}")
print(f"y_val: min={y_val.min()}, max={y_val.max()}, mean={y_val.mean():.4f}")
# Out:
# 1D Convex Function - Summary Statistics:
# X_train: min=0.0, max=1.0, mean=0.4979
# y_train: min=0.0, max=1.0, mean=0.3318
# X_val: min=0.01001001001001001, max=0.998998998998999, mean=0.5083
# y_val: min=0.0001002003004005006, max=0.9979990000010021, mean=0.3403

# %% [markdown]
# ### 1D Non-Convex Data Generation

# %%
X_train_nc, X_val_nc, y_train_nc, y_val_nc = generate_1d_non_convex(n_samples=1000)
print(f"Training set size: {X_train_nc.shape[0]} samples")
print(f"Validation set size: {X_val_nc.shape[0]} samples")
# Out:
# Training set size: 800 samples
# Validation set size: 200 samples

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_train_nc, y_train_nc, label='Train Data', color='red', alpha=0.5)
plt.scatter(X_val_nc, y_val_nc, label='Validation Data', color='orange', alpha=0.5)
plt.title('1D Non-Convex Function: Training and Validation Data')
plt.xlabel('X')
plt.ylabel('f(X) = sin(2πX)')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("1D Non-Convex Function - Summary Statistics:")
print(f"X_train: min={X_train_nc.min()}, max={X_train_nc.max()}, mean={X_train_nc.mean():.4f}")
print(f"y_train: min={y_train_nc.min()}, max={y_train_nc.max()}, mean={y_train_nc.mean():.4f}")
print(f"X_val: min={X_val_nc.min()}, max={X_val_nc.max()}, mean={X_val_nc.mean():.4f}")
print(f"y_val: min={y_val_nc.min()}, max={y_val_nc.max()}, mean={y_val_nc.mean():.4f}")
# Out:
# 1D Non-Convex Function - Summary Statistics:
# X_train: min=0.0, max=1.0, mean=0.4979
# y_train: min=-0.999988874475714, max=0.9999987638285974, mean=-0.0013
# X_val: min=0.01001001001001001, max=0.998998998998999, mean=0.5083
# y_val: min=-0.9999987638285974, max=0.9998504269583004, mean=0.0051

# %% [markdown]
# ### 2D Convex Data Generation

# %% [markdown]
# Since we are working on 2D, 10000 samples should be enough to get a good approximation of the function

# %%
n_samples = 10000
X_train, X_val, y_train, y_val = generate_2d_convex(n_samples=n_samples)
print(f"Training set size: {X_train.shape[0]} samples")
print(f"Validation set size: {X_val.shape[0]} samples")
print(f"Input Dimensions: {X_train.shape[1]}")
# Out:
# Training set size: 8000 samples
# Validation set size: 2000 samples
# Input Dimensions: 2

# %% [markdown]
# Scatter plot for the 2D Convex Data Generation.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='viridis', alpha=0.5)
plt.title('2D Convex Function: Training Data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar(label='f(X) = X1² + X2²')
plt.grid(True)
plt.show()

# %%
print("2D Convex Function - Summary Statistics:")
print(f"X_train: min={X_train.min()}, max={X_train.max()}, mean={X_train.mean():.4f}")
print(f"y_train: min={y_train.min()}, max={y_train.max()}, mean={y_train.mean():.4f}")
print(f"X_val: min={X_val.min()}, max={X_val.max()}, mean={X_val.mean():.4f}")
print(f"y_val: min={y_val.min()}, max={y_val.max()}, mean={y_val.mean():.4f}")
# Out:
# 2D Convex Function - Summary Statistics:
# X_train: min=0.0, max=1.0, mean=0.5021
# y_train: min=0.0001020304050607081, max=2.0, mean=0.6739
# X_val: min=0.0, max=1.0, mean=0.4917
# y_val: min=0.0, max=1.9799000102030406, mean=0.6546

# %% [markdown]
# ### 2D Non-Convex Data Generation

# %%
X_train_nc, X_val_nc, y_train_nc, y_val_nc = generate_2d_non_convex(n_samples=n_samples)
print(f"Training set size: {X_train_nc.shape[0]} samples")
print(f"Validation set size: {X_val_nc.shape[0]} samples")
print(f"Input Dimensions: {X_train_nc.shape[1]}")
# Out:
# Training set size: 8000 samples
# Validation set size: 2000 samples
# Input Dimensions: 2

# %% [markdown]
# Scatter plot for the 2D Non-Convex Data Generation.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_train_nc[:, 0], X_train_nc[:, 1], c=y_train_nc, cmap='viridis', alpha=0.5)
plt.title('2D Non-Convex Function: Training Data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar(label='f(X) = sin(2πX1) + sin(2πX2)')
plt.grid(True)
plt.show()

# %%
print("2D Non-Convex Function - Summary Statistics:")
print(f"X_train: min={X_train_nc.min()}, max={X_train_nc.max()}, mean={X_train_nc.mean():.4f}")
print(f"y_train: min={y_train_nc.min()}, max={y_train_nc.max()}, mean={y_train_nc.mean():.4f}")
print(f"X_val: min={X_val_nc.min()}, max={X_val_nc.max()}, mean={X_val_nc.mean():.4f}")
print(f"y_val: min={y_val_nc.min()}, max={y_val_nc.max()}, mean={y_val_nc.mean():.4f}")
# Out:
# 2D Non-Convex Function - Summary Statistics:
# X_train: min=0.0, max=1.0, mean=0.5021
# y_train: min=-0.9998741276738751, max=0.9998741276738751, mean=0.0018
# X_val: min=0.0, max=1.0, mean=0.4917
# y_val: min=-0.9998741276738751, max=0.9993707334284415, mean=-0.0072
